# %%
from xgboost import XGBClassifier
from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn import metrics

import random
import pandas as pd 
import numpy as np

# %%
data_le = pd.read_csv('Data/encoded_data.csv')
features = data_le.columns.tolist()
features.remove('y')

# %%
def CVXgb(df, n_splits=5,  rando_state=2021, features=features, if_print=True, 
                  *args, **kwargs):
    # Prepare KStratifiedKFOLD
    kf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=rando_state)
    
    # Make copy of data
    data = df.copy()
    
    # Prepare empty lists
    train_results = []
    test_results = []
    preds = []
    indicies = []
    # Prepare int to count fold s
    fold_number = 1
       
    for train, test in kf.split(data.index.values, data['y']):
        # Prepare KNN model 
        model = XGBClassifier(use_label_encoder=False, *args, **kwargs)
        model.fit(data.loc[train, features], data.loc[train, 'y'])
        
        # Make predictions
        train_preds = model.predict(data.loc[train, features])
        test_preds = model.predict(data.loc[test, features])
        preds.append(test_preds)
        
        # Add indicies of test data
        indicies.append(df.iloc[test].index.tolist().copy())
        
        # Prepare ROC_AUC score
        train_roc = metrics.roc_auc_score(data.loc[train, 'y'], train_preds)
        test_roc = metrics.roc_auc_score(data.loc[test, 'y'], test_preds)
        
        # Add ROC_AUC to lis
        train_results.append(train_roc)
        test_results.append(test_roc)
        
        if if_print:
            print(f'FOLD NUMBER: {fold_number}')
            print(f'ROC_AUC ON TRAIN SCORE {train_roc}')
            print(f'ROC_AUC ON TEST SCORE {test_roc}')
                  
        fold_number += 1 
        
    return train_results, test_results, preds, indicies

# %%
# Test basic model 
train_results, test_results, preds, indicies  = CVXgb(data_le, **{ 
    'max_depth': 8, 
    'subsample': 0.7, 
    'colsample_bytree': 0.7,
})
# Out:
# [13:10:56] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 1
# ROC_AUC ON TRAIN SCORE 0.8773112229617339
# ROC_AUC ON TEST SCORE 0.7859788526067999
# [13:10:58] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 2
# ROC_AUC ON TRAIN SCORE 0.8734216973933209
# ROC_AUC ON TEST SCORE 0.7866418670819156
# [13:10:59] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 3
# ROC_AUC ON TRAIN SCORE 0.8733733809154742
# ROC_AUC ON TEST SCORE 0.7968434112448131
# [13:11:01] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 4
# ROC_AUC ON TRAIN SCORE 0.876954286026812
# ROC_AUC ON TEST SCORE 0.7933740087884272
# [13:11:05] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 5
# ROC_AUC ON TRAIN SCORE 0.8766545120635696
# ROC_AUC ON TEST SCORE 0.8006030318467773

# %%
def XGB_h_param():
    test_list = []
    for i in range(50):
        
        param_dict = {
        'max_depth': random.randrange(4, 14, 1),
        'subsample': random.choice([x/10 for x in list(range(3,10))]), 
        'colsample_bytree': random.choice([x/10 for x in list(range(3,10))]),
        'reg_lambda': random.choice([(x/10)**2 for x in list(range(2, 8))])
        }

        # Use gamme if lambda is low and in half situations (in order to try models without L2 and gamma)
        if (param_dict['reg_lambda']) and (random.randrange(0,2,1) == 1):
            param_dict['gamma'] = random.choice([0, 0.01, 0.1, 0.5, 1, 2, 5])
            
        train_results, test_results, preds, indicies  = CVXgb(data_le, **param_dict)
        test_list.append([param_dict.items(), np.mean(test_results)])
        
        print([param_dict.items(), np.mean(train_results), np.mean(test_results)])
            
    return test_list

# %%
tune_xgb = XGB_h_param()
# Out:
# [13:37:37] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 1
# ROC_AUC ON TRAIN SCORE 0.8548742055462326
# ROC_AUC ON TEST SCORE 0.7794619826613569
# [13:37:39] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 2
# ROC_AUC ON TRAIN SCORE 0.8555974547971332
# ROC_AUC ON TEST SCORE 0.7837485821942827
# [13:37:40] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 3
# ROC_AUC ON TRAIN SCORE 0.8521692152472983
# ROC_AUC ON TEST SCORE 0.7952716554129398
# [13:37:42] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 4
# ROC_AUC ON TRAIN SCORE 0.8536492054890735
# ROC_AUC ON TEST SCORE 0.7908912616525609
# [13:37:45] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 5
# ROC_AUC ON TRAIN SCORE 0.8512001105356445
# ROC_AUC ON TEST SCORE 0.80165913222356
# [dict_items([('max_depth', 7), ('subsample', 0.4), ('colsample_bytree', 0.9), ('reg_lambda', 0.48999999999999994)]), 0.8534980383230764, 0.79020652282894]
# [13:37:49] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 1
# ROC_AUC ON TRAIN SCORE 0.9516130692814944
# ROC_AUC ON TEST SCORE 0.7816172833409253
# [13:37:55] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 2
# ROC_AUC ON TRAIN SCORE 0.9513077178872956
# ROC_AUC ON TEST SCORE 0.778834568017204
# [13:38:00] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 3
# ROC_AUC ON TRAIN SCORE 0.9509503690638365
# ROC_AUC ON TEST SCORE 0.7860445322469501
# [13:38:05] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 4
# ROC_AUC ON TRAIN SCORE 0.9518624716374603
# ROC_AUC ON TEST SCORE 0.7842504485856961
# [13:38:13] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 5
# ROC_AUC ON TRAIN SCORE 0.9507773800605498
# ROC_AUC ON TEST SCORE 0.7867363052016938
# [dict_items([('max_depth', 11), ('subsample', 0.6), ('colsample_bytree', 0.8), ('reg_lambda', 0.25)]), 0.9513022015861274, 0.7834966274784939]
# [13:38:19] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 1
# ROC_AUC ON TRAIN SCORE 0.8559632258522624
# ROC_AUC ON TEST SCORE 0.7839890033647453
# [13:38:22] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 2
# ROC_AUC ON TRAIN SCORE 0.8579549479196917
# ROC_AUC ON TEST SCORE 0.7832750209828916
# [13:38:25] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 3
# ROC_AUC ON TRAIN SCORE 0.8535929373768077
# ROC_AUC ON TEST SCORE 0.7927994459597403
# [13:38:28] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 4
# ROC_AUC ON TRAIN SCORE 0.8576599006762392
# ROC_AUC ON TEST SCORE 0.7829425666927345
# [13:38:30] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 5
# ROC_AUC ON TRAIN SCORE 0.8550046884096612
# ROC_AUC ON TEST SCORE 0.7898646149625765
# [dict_items([('max_depth', 8), ('subsample', 0.3), ('colsample_bytree', 0.7), ('reg_lambda', 0.48999999999999994), ('gamma', 0)]), 0.8560351400469324, 0.7865741303925378]
# [13:38:33] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 1
# ROC_AUC ON TRAIN SCORE 0.967916897351739
# ROC_AUC ON TEST SCORE 0.7860675787821094
# [13:38:40] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 2
# ROC_AUC ON TRAIN SCORE 0.9633333931412407
# ROC_AUC ON TEST SCORE 0.7861083013049971
# [13:38:54] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 3
# ROC_AUC ON TRAIN SCORE 0.9676898805912794
# ROC_AUC ON TEST SCORE 0.7924093789521709
# [13:39:15] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 4
# ROC_AUC ON TRAIN SCORE 0.9640793733722799
# ROC_AUC ON TEST SCORE 0.7863189438685284
# [13:39:20] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 5
# ROC_AUC ON TRAIN SCORE 0.9667278282840276
# ROC_AUC ON TEST SCORE 0.794018966792307
# [dict_items([('max_depth', 13), ('subsample', 0.9), ('colsample_bytree', 0.7), ('reg_lambda', 0.36), ('gamma', 0.5)]), 0.9659494745481133, 0.7889846339400225]
# [13:39:33] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 1
# ROC_AUC ON TRAIN SCORE 0.8127572936534713
# ROC_AUC ON TEST SCORE 0.7903909868710586
# [13:39:35] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 2
# ROC_AUC ON TRAIN SCORE 0.8161753677383826
# ROC_AUC ON TEST SCORE 0.7933438734158651
# [13:39:37] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 3
# ROC_AUC ON TRAIN SCORE 0.8169375329681914
# ROC_AUC ON TEST SCORE 0.7971141087651236
# [13:39:39] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 4
# ROC_AUC ON TRAIN SCORE 0.8154756127136141
# ROC_AUC ON TEST SCORE 0.7992641415269517
# [13:39:40] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 5
# ROC_AUC ON TRAIN SCORE 0.8102000795914212
# ROC_AUC ON TEST SCORE 0.8051421818427434
# [dict_items([('max_depth', 4), ('subsample', 0.7), ('colsample_bytree', 0.9), ('reg_lambda', 0.36)]), 0.8143091773330162, 0.7970510584843484]
# [13:39:42] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 1
# ROC_AUC ON TRAIN SCORE 0.8125403496458069
# ROC_AUC ON TEST SCORE 0.7918087062509159
# [13:39:46] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 2
# ROC_AUC ON TRAIN SCORE 0.8150190617372918
# ROC_AUC ON TEST SCORE 0.7956795907003686
# [13:39:49] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 3
# ROC_AUC ON TRAIN SCORE 0.8144246785219024
# ROC_AUC ON TEST SCORE 0.7968328735621462
# [13:39:52] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 4
# ROC_AUC ON TRAIN SCORE 0.8111739590687084
# ROC_AUC ON TEST SCORE 0.7983289653774934
# [13:39:55] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 5
# ROC_AUC ON TRAIN SCORE 0.809100444229514
# ROC_AUC ON TEST SCORE 0.8080460044130433
# [dict_items([('max_depth', 4), ('subsample', 0.9), ('colsample_bytree', 0.6), ('reg_lambda', 0.16000000000000003)]), 0.8124516986406448, 0.7981392280607935]
# [13:39:58] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 1
# ROC_AUC ON TRAIN SCORE 0.9787439512506395
# ROC_AUC ON TEST SCORE 0.7698885348283765
# [13:40:05] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 2
# ROC_AUC ON TRAIN SCORE 0.9815590918174305
# ROC_AUC ON TEST SCORE 0.7837220190221091
# [13:40:12] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 3
# ROC_AUC ON TRAIN SCORE 0.9781955523795748
# ROC_AUC ON TEST SCORE 0.7808908280528314
# [13:40:18] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 4
# ROC_AUC ON TRAIN SCORE 0.9800220351655912
# ROC_AUC ON TEST SCORE 0.778485904294693
# [13:40:25] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 5
# ROC_AUC ON TRAIN SCORE 0.9818173722309418
# ROC_AUC ON TEST SCORE 0.7858910448526962
# [dict_items([('max_depth', 13), ('subsample', 0.6), ('colsample_bytree', 0.9), ('reg_lambda', 0.36)]), 0.9800676005688356, 0.7797756662101412]
# [13:40:31] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 1
# ROC_AUC ON TRAIN SCORE 0.8178763737160211
# ROC_AUC ON TEST SCORE 0.791371147778841
# [13:40:33] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 2
# ROC_AUC ON TRAIN SCORE 0.8180044587190781
# ROC_AUC ON TEST SCORE 0.7911787302608002
# [13:40:36] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 3
# ROC_AUC ON TRAIN SCORE 0.8162267729420833
# ROC_AUC ON TEST SCORE 0.7974437136590306
# [13:40:39] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 4
# ROC_AUC ON TRAIN SCORE 0.8181993592386857
# ROC_AUC ON TEST SCORE 0.7978564107719992
# [13:40:43] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 5
# ROC_AUC ON TRAIN SCORE 0.8169395155573882
# ROC_AUC ON TEST SCORE 0.8083793234082184
# [dict_items([('max_depth', 8), ('subsample', 0.4), ('colsample_bytree', 0.4), ('reg_lambda', 0.36), ('gamma', 5)]), 0.8174492960346514, 0.7972458651757779]
# [13:40:48] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 1
# ROC_AUC ON TRAIN SCORE 0.8107706311478805
# ROC_AUC ON TEST SCORE 0.7890547125369769
# [13:40:50] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 2
# ROC_AUC ON TRAIN SCORE 0.8123103608930041
# ROC_AUC ON TEST SCORE 0.7900588752709703
# [13:40:52] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 3
# ROC_AUC ON TRAIN SCORE 0.8096451920952621
# ROC_AUC ON TEST SCORE 0.7939532358373113
# [13:40:54] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 4
# ROC_AUC ON TRAIN SCORE 0.8077429031582538
# ROC_AUC ON TEST SCORE 0.798394696332489
# [13:40:56] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 5
# ROC_AUC ON TRAIN SCORE 0.8090888365475746
# ROC_AUC ON TEST SCORE 0.7953715042749306
# [dict_items([('max_depth', 4), ('subsample', 0.3), ('colsample_bytree', 0.8), ('reg_lambda', 0.04000000000000001)]), 0.8099115847683951, 0.7933666048505356]
# [13:40:58] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 1
# ROC_AUC ON TRAIN SCORE 0.902660768513041
# ROC_AUC ON TEST SCORE 0.7903280180512152
# [13:41:03] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 2
# ROC_AUC ON TRAIN SCORE 0.8987716945627012
# ROC_AUC ON TEST SCORE 0.78900158619263
# [13:41:06] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 3
# ROC_AUC ON TRAIN SCORE 0.8998259747250461
# ROC_AUC ON TEST SCORE 0.796500159188108
# [13:41:11] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 4
# ROC_AUC ON TRAIN SCORE 0.9071665022305029
# ROC_AUC ON TEST SCORE 0.7893021445566217
# [13:41:16] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 5
# ROC_AUC ON TRAIN SCORE 0.900263331742944
# ROC_AUC ON TEST SCORE 0.8023198967514397
# [dict_items([('max_depth', 9), ('subsample', 0.8), ('colsample_bytree', 0.6), ('reg_lambda', 0.09)]), 0.9017376543548471, 0.7934903609480028]
# [13:41:19] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 1
# ROC_AUC ON TRAIN SCORE 0.918814866299675
# ROC_AUC ON TEST SCORE 0.7822854205079661
# [13:41:27] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 2
# ROC_AUC ON TRAIN SCORE 0.9191939897760002
# ROC_AUC ON TEST SCORE 0.777183708596418
# [13:41:39] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 3
# ROC_AUC ON TRAIN SCORE 0.9131209156323741
# ROC_AUC ON TEST SCORE 0.7877387670462133
# [13:41:44] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 4
# ROC_AUC ON TRAIN SCORE 0.913089035885944
# ROC_AUC ON TEST SCORE 0.7873734895052454
# [13:41:52] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 5
# ROC_AUC ON TRAIN SCORE 0.9124443129914644
# ROC_AUC ON TEST SCORE 0.7887223128866013
# [dict_items([('max_depth', 10), ('subsample', 0.5), ('colsample_bytree', 0.8), ('reg_lambda', 0.36), ('gamma', 1)]), 0.9153326241170916, 0.7846607397084888]
# [13:41:59] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 1
# ROC_AUC ON TRAIN SCORE 0.8668973150337546
# ROC_AUC ON TEST SCORE 0.7878915736782965
# [13:42:02] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 2
# ROC_AUC ON TRAIN SCORE 0.8631039661221528
# ROC_AUC ON TEST SCORE 0.7902894539659363
# [13:42:06] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 3
# ROC_AUC ON TRAIN SCORE 0.8581992153120652
# ROC_AUC ON TEST SCORE 0.800052653863555
# [13:42:10] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 4
# ROC_AUC ON TRAIN SCORE 0.8620259039131489
# ROC_AUC ON TEST SCORE 0.7946456134131916
# [13:42:14] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 5
# ROC_AUC ON TRAIN SCORE 0.8592343571553478
# ROC_AUC ON TEST SCORE 0.7989949987467068
# [dict_items([('max_depth', 7), ('subsample', 0.6), ('colsample_bytree', 0.8), ('reg_lambda', 0.48999999999999994), ('gamma', 0.01)]), 0.8618921515072937, 0.7943748587335372]
# [13:42:18] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 1
# ROC_AUC ON TRAIN SCORE 0.911660393961523
# ROC_AUC ON TEST SCORE 0.786545859777072
# [13:42:22] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 2
# ROC_AUC ON TRAIN SCORE 0.9137160046924521
# ROC_AUC ON TEST SCORE 0.789655161100603
# [13:42:26] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 3
# ROC_AUC ON TRAIN SCORE 0.9143975807374368
# ROC_AUC ON TEST SCORE 0.7956254451523119
# [13:42:30] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 4
# ROC_AUC ON TRAIN SCORE 0.9157794346130569
# ROC_AUC ON TEST SCORE 0.7910137406199508
# [13:42:34] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 5
# ROC_AUC ON TRAIN SCORE 0.9153588990189242
# ROC_AUC ON TEST SCORE 0.7952043697178786
# [dict_items([('max_depth', 10), ('subsample', 0.8), ('colsample_bytree', 0.6), ('reg_lambda', 0.48999999999999994)]), 0.9141824626046786, 0.7916089152735631]
# [13:42:38] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 1
# ROC_AUC ON TRAIN SCORE 0.8115659899506307
# ROC_AUC ON TEST SCORE 0.7945455763598245
# [13:42:41] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 2
# ROC_AUC ON TRAIN SCORE 0.8113158547135088
# ROC_AUC ON TEST SCORE 0.7958501648298074
# [13:42:43] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 3
# ROC_AUC ON TRAIN SCORE 0.8112668061315619
# ROC_AUC ON TEST SCORE 0.7962341258879941
# [13:42:45] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 4
# ROC_AUC ON TRAIN SCORE 0.8111621318986727
# ROC_AUC ON TEST SCORE 0.796776125549752
# [13:42:46] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 5
# ROC_AUC ON TRAIN SCORE 0.8080683140507644
# ROC_AUC ON TEST SCORE 0.802812922101131
# [dict_items([('max_depth', 4), ('subsample', 0.7), ('colsample_bytree', 0.4), ('reg_lambda', 0.48999999999999994)]), 0.8106758193490278, 0.7972437829457018]
# [13:42:49] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 1
# ROC_AUC ON TRAIN SCORE 0.9151263665513072
# ROC_AUC ON TEST SCORE 0.7907004492658377
# [13:42:53] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 2
# ROC_AUC ON TRAIN SCORE 0.9138194990014671
# ROC_AUC ON TEST SCORE 0.7917024535622221
# [13:42:58] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 3
# ROC_AUC ON TRAIN SCORE 0.9171602594133407
# ROC_AUC ON TEST SCORE 0.7979615284753234
# [13:43:02] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 4
# ROC_AUC ON TRAIN SCORE 0.9166488593455513
# ROC_AUC ON TEST SCORE 0.7859825153932223
# [13:43:06] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 5
# ROC_AUC ON TRAIN SCORE 0.9169877849477223
# ROC_AUC ON TEST SCORE 0.7979615284753234
# [dict_items([('max_depth', 12), ('subsample', 0.9), ('colsample_bytree', 0.4), ('reg_lambda', 0.04000000000000001), ('gamma', 1)]), 0.9159485538518778, 0.7928616950343857]
# [13:43:10] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 1
# ROC_AUC ON TRAIN SCORE 0.8350307047750848
# ROC_AUC ON TEST SCORE 0.7869761371196128
# [13:43:13] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 2
# ROC_AUC ON TRAIN SCORE 0.8372872693550515
# ROC_AUC ON TEST SCORE 0.7931921784207121
# [13:43:16] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 3
# ROC_AUC ON TRAIN SCORE 0.8354279406187549
# ROC_AUC ON TEST SCORE 0.8000889311317523
# [13:43:18] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 4
# ROC_AUC ON TRAIN SCORE 0.8380362148162381
# ROC_AUC ON TEST SCORE 0.7960328734239471
# [13:43:20] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 5
# ROC_AUC ON TRAIN SCORE 0.8354653291565828
# ROC_AUC ON TEST SCORE 0.7987432172305277
# [dict_items([('max_depth', 7), ('subsample', 0.4), ('colsample_bytree', 0.4), ('reg_lambda', 0.16000000000000003), ('gamma', 1)]), 0.8362494917443424, 0.7950066674653105]
# [13:43:23] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 1
# ROC_AUC ON TRAIN SCORE 0.8280151040947631
# ROC_AUC ON TEST SCORE 0.7942138676680895
# [13:43:25] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 2
# ROC_AUC ON TRAIN SCORE 0.8294962206512486
# ROC_AUC ON TEST SCORE 0.7948455991874604
# [13:43:27] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 3
# ROC_AUC ON TRAIN SCORE 0.8261592677589258
# ROC_AUC ON TEST SCORE 0.7960443612255429
# [13:43:29] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 4
# ROC_AUC ON TRAIN SCORE 0.8299186706649482
# ROC_AUC ON TEST SCORE 0.7979236964670605
# [13:43:32] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 5
# ROC_AUC ON TRAIN SCORE 0.8256094500779723
# ROC_AUC ON TEST SCORE 0.8053545766105942
# [dict_items([('max_depth', 6), ('subsample', 0.7), ('colsample_bytree', 0.3), ('reg_lambda', 0.36), ('gamma', 0.01)]), 0.8278397426495715, 0.7976764202317496]
# [13:43:35] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 1
# ROC_AUC ON TRAIN SCORE 0.8305485807252515
# ROC_AUC ON TEST SCORE 0.7898308579219668
# [13:43:37] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 2
# ROC_AUC ON TRAIN SCORE 0.8293051502208381
# ROC_AUC ON TEST SCORE 0.7947590314497598
# [13:43:40] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 3
# ROC_AUC ON TRAIN SCORE 0.8304042143153735
# ROC_AUC ON TEST SCORE 0.7982201335729014
# [13:43:42] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 4
# ROC_AUC ON TRAIN SCORE 0.828780617689877
# ROC_AUC ON TEST SCORE 0.7970558060126635
# [13:43:44] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 5
# ROC_AUC ON TRAIN SCORE 0.8263689112742759
# ROC_AUC ON TEST SCORE 0.8062345594877236
# [dict_items([('max_depth', 6), ('subsample', 0.5), ('colsample_bytree', 0.4), ('reg_lambda', 0.16000000000000003), ('gamma', 0.01)]), 0.8290814948451232, 0.797220077689003]
# [13:43:46] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 1
# ROC_AUC ON TRAIN SCORE 0.8953324268153093
# ROC_AUC ON TEST SCORE 0.7836958587582894
# [13:43:50] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 2
# ROC_AUC ON TRAIN SCORE 0.894870479103369
# ROC_AUC ON TEST SCORE 0.7816940086031294
# [13:43:54] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 3
# ROC_AUC ON TRAIN SCORE 0.893680721820787
# ROC_AUC ON TEST SCORE 0.7905390266532545
# [13:44:00] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 4
# ROC_AUC ON TRAIN SCORE 0.8940261852896919
# ROC_AUC ON TEST SCORE 0.7865139773723131
# [13:44:05] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 5
# ROC_AUC ON TRAIN SCORE 0.8959668918398644
# ROC_AUC ON TEST SCORE 0.7972198310895843
# [dict_items([('max_depth', 9), ('subsample', 0.5), ('colsample_bytree', 0.7), ('reg_lambda', 0.16000000000000003), ('gamma', 0.01)]), 0.8947753409738043, 0.7879325404953141]
# [13:44:09] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 1
# ROC_AUC ON TRAIN SCORE 0.8625837848686397
# ROC_AUC ON TEST SCORE 0.780689845869136
# [13:44:13] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 2
# ROC_AUC ON TRAIN SCORE 0.8661506860010159
# ROC_AUC ON TEST SCORE 0.7876460298159089
# [13:44:16] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 3
# ROC_AUC ON TRAIN SCORE 0.8632633418178075
# ROC_AUC ON TEST SCORE 0.7961379911272712
# [13:44:20] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 4
# ROC_AUC ON TRAIN SCORE 0.8642846739018579
# ROC_AUC ON TEST SCORE 0.7864814142053835
# [13:44:24] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 5
# ROC_AUC ON TRAIN SCORE 0.8630572245046585
# ROC_AUC ON TEST SCORE 0.7973664949024393
# [dict_items([('max_depth', 8), ('subsample', 0.4), ('colsample_bytree', 0.9), ('reg_lambda', 0.48999999999999994), ('gamma', 2)]), 0.8638679422187959, 0.7896643551840279]
# [13:44:30] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 1
# ROC_AUC ON TRAIN SCORE 0.9456942581774791
# ROC_AUC ON TEST SCORE 0.7795194258809218
# [13:44:36] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 2
# ROC_AUC ON TRAIN SCORE 0.941247511476461
# ROC_AUC ON TEST SCORE 0.7759605651722106
# [13:44:41] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 3
# ROC_AUC ON TRAIN SCORE 0.9389054272569674
# ROC_AUC ON TEST SCORE 0.7854510534141315
# [13:44:46] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 4
# ROC_AUC ON TRAIN SCORE 0.9454624002498566
# ROC_AUC ON TEST SCORE 0.7838278184111972
# [13:44:51] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 5
# ROC_AUC ON TRAIN SCORE 0.9444589186649079
# ROC_AUC ON TEST SCORE 0.7842898353340247
# [dict_items([('max_depth', 13), ('subsample', 0.5), ('colsample_bytree', 0.6), ('reg_lambda', 0.04000000000000001), ('gamma', 1)]), 0.9431537031651344, 0.7818097396424972]
# [13:44:56] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 1
# ROC_AUC ON TRAIN SCORE 0.8856081972617075
# ROC_AUC ON TEST SCORE 0.7883407301551232
# [13:45:00] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 2
# ROC_AUC ON TRAIN SCORE 0.8898241959157922
# ROC_AUC ON TEST SCORE 0.7877806012060313
# [13:45:03] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 3
# ROC_AUC ON TRAIN SCORE 0.8855026493292659
# ROC_AUC ON TEST SCORE 0.7955876131440489
# [13:45:07] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 4
# ROC_AUC ON TRAIN SCORE 0.8853710896036766
# ROC_AUC ON TEST SCORE 0.7857738347266395
# [13:45:11] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 5
# ROC_AUC ON TRAIN SCORE 0.8873195825840152
# ROC_AUC ON TEST SCORE 0.7918900093958124
# [dict_items([('max_depth', 9), ('subsample', 0.5), ('colsample_bytree', 0.5), ('reg_lambda', 0.09)]), 0.8867251429388915, 0.7898745577255312]
# [13:45:14] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 1
# ROC_AUC ON TRAIN SCORE 0.8297925198919589
# ROC_AUC ON TEST SCORE 0.7888361347551163
# [13:45:17] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 2
# ROC_AUC ON TRAIN SCORE 0.8264809575005586
# ROC_AUC ON TEST SCORE 0.7973326085587633
# [13:45:19] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 3
# ROC_AUC ON TRAIN SCORE 0.8276631318288685
# ROC_AUC ON TEST SCORE 0.7953042185798694
# [13:45:22] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 4
# ROC_AUC ON TRAIN SCORE 0.8286545667556853
# ROC_AUC ON TEST SCORE 0.7955944367254479
# [13:45:24] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 5
# ROC_AUC ON TRAIN SCORE 0.8248853948302997
# ROC_AUC ON TEST SCORE 0.8032823672264939
# [dict_items([('max_depth', 5), ('subsample', 0.6), ('colsample_bytree', 0.8), ('reg_lambda', 0.48999999999999994)]), 0.8274953141614741, 0.7960699531691382]
# [13:45:27] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 1
# ROC_AUC ON TRAIN SCORE 0.8226392584660108
# ROC_AUC ON TEST SCORE 0.7854984131742283
# [13:45:30] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 2
# ROC_AUC ON TRAIN SCORE 0.8245796849970058
# ROC_AUC ON TEST SCORE 0.7932667452453074
# [13:45:32] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 3
# ROC_AUC ON TRAIN SCORE 0.8199838982093369
# ROC_AUC ON TEST SCORE 0.7997540573965117
# [13:45:33] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 4
# ROC_AUC ON TRAIN SCORE 0.8217036486117918
# ROC_AUC ON TEST SCORE 0.7994576202906707
# [13:45:35] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 5
# ROC_AUC ON TRAIN SCORE 0.8166954951687432
# ROC_AUC ON TEST SCORE 0.797088369179593
# [dict_items([('max_depth', 6), ('subsample', 0.3), ('colsample_bytree', 0.3), ('reg_lambda', 0.25), ('gamma', 0.5)]), 0.8211203970905776, 0.7950130410572622]
# [13:45:38] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 1
# ROC_AUC ON TRAIN SCORE 0.8917521732617371
# ROC_AUC ON TEST SCORE 0.7894558653613818
# [13:45:44] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 2
# ROC_AUC ON TRAIN SCORE 0.8927105427982867
# ROC_AUC ON TEST SCORE 0.7882468812878883
# [13:45:48] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 3
# ROC_AUC ON TRAIN SCORE 0.8921028147009529
# ROC_AUC ON TEST SCORE 0.7946245380478579
# [13:45:54] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 4
# ROC_AUC ON TRAIN SCORE 0.8908517865251581
# ROC_AUC ON TEST SCORE 0.7936794288368697
# [13:45:58] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 5
# ROC_AUC ON TRAIN SCORE 0.8914021187437797
# ROC_AUC ON TEST SCORE 0.7990070911694391
# [dict_items([('max_depth', 8), ('subsample', 0.8), ('colsample_bytree', 0.9), ('reg_lambda', 0.25)]), 0.8917638872059829, 0.7930027609406873]
# [13:46:05] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 1
# ROC_AUC ON TRAIN SCORE 0.9599851705178136
# ...
# FOLD NUMBER: 4
# ROC_AUC ON TRAIN SCORE 0.9182611433386804
# ROC_AUC ON TEST SCORE 0.784043322659179
# [13:53:05] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 5
# ROC_AUC ON TRAIN SCORE 0.9182076674028514
# ROC_AUC ON TEST SCORE 0.7882444894397737
# [dict_items([('max_depth', 11), ('subsample', 0.5), ('colsample_bytree', 0.8), ('reg_lambda', 0.16000000000000003), ('gamma', 2)]), 0.9177341951103151, 0.7820646277424187]
# [13:53:10] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 1
# ROC_AUC ON TRAIN SCORE 0.9623491500274375
# ROC_AUC ON TEST SCORE 0.7806319997412177
# [13:53:16] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 2
# ROC_AUC ON TRAIN SCORE 0.9596672979675575
# ROC_AUC ON TEST SCORE 0.7773255611160745
# [13:53:21] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 3
# ROC_AUC ON TRAIN SCORE 0.9651488920888575
# ROC_AUC ON TEST SCORE 0.7908859928112275
# [13:53:27] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 4
# ROC_AUC ON TRAIN SCORE 0.9646904534192287
# ROC_AUC ON TEST SCORE 0.7786031144207496
# [13:53:32] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 5
# ROC_AUC ON TRAIN SCORE 0.9662201739065355
# ROC_AUC ON TEST SCORE 0.7920865976396628
# [dict_items([('max_depth', 12), ('subsample', 0.7), ('colsample_bytree', 0.7), ('reg_lambda', 0.04000000000000001), ('gamma', 0.1)]), 0.9636151934819234, 0.7839066531457864]
# [13:53:39] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 1
# ROC_AUC ON TRAIN SCORE 0.8231624571040199
# ROC_AUC ON TEST SCORE 0.790650287175807
# [13:53:41] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 2
# ROC_AUC ON TRAIN SCORE 0.8243287184947453
# ROC_AUC ON TEST SCORE 0.7946004582334265
# [13:53:43] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 3
# ROC_AUC ON TRAIN SCORE 0.8236574308954323
# ROC_AUC ON TEST SCORE 0.7932992948908305
# [13:53:46] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 4
# ROC_AUC ON TRAIN SCORE 0.8222118175269522
# ROC_AUC ON TEST SCORE 0.7960827978549424
# [13:53:48] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 5
# ROC_AUC ON TRAIN SCORE 0.8191998291591015
# ROC_AUC ON TEST SCORE 0.7950955379132866
# [dict_items([('max_depth', 5), ('subsample', 0.4), ('colsample_bytree', 0.7), ('reg_lambda', 0.04000000000000001)]), 0.8225120506360503, 0.7939456752136586]
# [13:53:50] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 1
# ROC_AUC ON TRAIN SCORE 0.8126006973357298
# ROC_AUC ON TEST SCORE 0.7937334282355182
# [13:53:52] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 2
# ROC_AUC ON TRAIN SCORE 0.816476798511939
# ROC_AUC ON TEST SCORE 0.792853591507797
# [13:53:54] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 3
# ROC_AUC ON TRAIN SCORE 0.8099394572671068
# ROC_AUC ON TEST SCORE 0.79218117766032
# [13:53:56] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 4
# ROC_AUC ON TRAIN SCORE 0.8142145204688842
# ROC_AUC ON TEST SCORE 0.7990796457058338
# [13:53:58] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 5
# ROC_AUC ON TRAIN SCORE 0.8082407885163828
# ROC_AUC ON TEST SCORE 0.8097696928991047
# [dict_items([('max_depth', 4), ('subsample', 0.7), ('colsample_bytree', 0.5), ('reg_lambda', 0.16000000000000003), ('gamma', 0.5)]), 0.8122944524200084, 0.7975235072017147]
# [13:54:00] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 1
# ROC_AUC ON TRAIN SCORE 0.8863392877538927
# ROC_AUC ON TEST SCORE 0.790842301785494
# [13:54:03] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 2
# ROC_AUC ON TRAIN SCORE 0.8818386077790094
# ROC_AUC ON TEST SCORE 0.7885905908927288
# [13:54:08] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 3
# ROC_AUC ON TRAIN SCORE 0.8850381873305714
# ROC_AUC ON TEST SCORE 0.7958220333961621
# [13:54:12] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 4
# ROC_AUC ON TRAIN SCORE 0.8883720603887314
# ROC_AUC ON TEST SCORE 0.791472648062647
# [13:54:16] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 5
# ROC_AUC ON TRAIN SCORE 0.8845536727554824
# ROC_AUC ON TEST SCORE 0.8027115184990746
# [dict_items([('max_depth', 8), ('subsample', 0.8), ('colsample_bytree', 0.7), ('reg_lambda', 0.09)]), 0.8852283632015375, 0.7938878185272213]
# [13:54:19] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 1
# ROC_AUC ON TRAIN SCORE 0.8564713375677908
# ROC_AUC ON TEST SCORE 0.7840010042778506
# [13:54:22] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 2
# ROC_AUC ON TRAIN SCORE 0.8547710908842832
# ROC_AUC ON TEST SCORE 0.7890037446302389
# [13:54:25] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 3
# ROC_AUC ON TRAIN SCORE 0.8534953155483207
# ROC_AUC ON TEST SCORE 0.792231706712452
# [13:54:29] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 4
# ROC_AUC ON TRAIN SCORE 0.8557761962640967
# ROC_AUC ON TEST SCORE 0.7982260070353717
# [13:54:32] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 5
# ROC_AUC ON TRAIN SCORE 0.8545565332970638
# ROC_AUC ON TEST SCORE 0.7955702518799831
# [dict_items([('max_depth', 7), ('subsample', 0.4), ('colsample_bytree', 0.9), ('reg_lambda', 0.48999999999999994), ('gamma', 0.5)]), 0.8550140947123109, 0.7918065429071793]
# [13:54:35] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 1
# ROC_AUC ON TRAIN SCORE 0.8118597234249177
# ROC_AUC ON TEST SCORE 0.7895835585303238
# [13:54:37] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 2
# ROC_AUC ON TRAIN SCORE 0.8124329347161497
# ROC_AUC ON TEST SCORE 0.7902705748316505
# [13:54:39] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 3
# ROC_AUC ON TRAIN SCORE 0.8127357787905414
# ROC_AUC ON TEST SCORE 0.7987894275602552
# [13:54:41] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 4
# ROC_AUC ON TRAIN SCORE 0.812747091422909
# ROC_AUC ON TEST SCORE 0.793896487824917
# [13:54:43] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 5
# ROC_AUC ON TRAIN SCORE 0.809885981331278
# ROC_AUC ON TEST SCORE 0.8075560885434832
# [dict_items([('max_depth', 4), ('subsample', 0.6), ('colsample_bytree', 0.7), ('reg_lambda', 0.25)]), 0.8119323019371592, 0.796019227458126]
# [13:54:45] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 1
# ROC_AUC ON TRAIN SCORE 0.8102327972054637
# ROC_AUC ON TEST SCORE 0.7937381480190897
# [13:54:47] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 2
# ROC_AUC ON TRAIN SCORE 0.8057407897370035
# ROC_AUC ON TEST SCORE 0.7877475627210312
# [13:54:49] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 3
# ROC_AUC ON TRAIN SCORE 0.8054775953028108
# ROC_AUC ON TEST SCORE 0.7937219250653295
# [13:54:51] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 4
# ROC_AUC ON TRAIN SCORE 0.807395457100152
# ROC_AUC ON TEST SCORE 0.7975215370367588
# [13:54:53] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 5
# ROC_AUC ON TRAIN SCORE 0.8021116230101245
# ROC_AUC ON TEST SCORE 0.8023487458171014
# [dict_items([('max_depth', 4), ('subsample', 0.5), ('colsample_bytree', 0.8), ('reg_lambda', 0.48999999999999994), ('gamma', 5)]), 0.8061916524711108, 0.795015583731862]
# [13:54:55] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 1
# ROC_AUC ON TRAIN SCORE 0.8212535592722056
# ROC_AUC ON TEST SCORE 0.7914289939067595
# [13:54:57] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 2
# ROC_AUC ON TRAIN SCORE 0.8215408063594273
# ROC_AUC ON TEST SCORE 0.7992406098466888
# [13:54:59] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 3
# ROC_AUC ON TRAIN SCORE 0.8215681237078087
# ROC_AUC ON TEST SCORE 0.7999022759494322
# [13:55:01] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 4
# ROC_AUC ON TRAIN SCORE 0.8216582541557012
# ROC_AUC ON TEST SCORE 0.8017763423496163
# [13:55:02] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# FOLD NUMBER: 5
# ROC_AUC ON TRAIN SCORE 0.8193690724720908
# ROC_AUC ON TEST SCORE 0.807996079982048
# [dict_items([('max_depth', 5), ('subsample', 0.9), ('colsample_bytree', 0.4), ('reg_lambda', 0.36)]), 0.8210779631934466, 0.8000688604069088]

# %%
sorted_xgb = sorted(tune_xgb, key=lambda x: x[-1], reverse=True)
sorted_xgb
# Out:
# [[dict_items([('max_depth', 5), ('subsample', 0.9), ('colsample_bytree', 0.4), ('reg_lambda', 0.36)]),
#   0.8000688604069088],
#  [dict_items([('max_depth', 5), ('subsample', 0.9), ('colsample_bytree', 0.9), ('reg_lambda', 0.04000000000000001), ('gamma', 0.5)]),
#   0.7993539195863975],
#  [dict_items([('max_depth', 5), ('subsample', 0.7), ('colsample_bytree', 0.4), ('reg_lambda', 0.16000000000000003), ('gamma', 0.01)]),
#   0.7982915556139341],
#  [dict_items([('max_depth', 4), ('subsample', 0.9), ('colsample_bytree', 0.6), ('reg_lambda', 0.16000000000000003)]),
#   0.7981392280607935],
#  [dict_items([('max_depth', 6), ('subsample', 0.7), ('colsample_bytree', 0.3), ('reg_lambda', 0.36), ('gamma', 0.01)]),
#   0.7976764202317496],
#  [dict_items([('max_depth', 4), ('subsample', 0.7), ('colsample_bytree', 0.5), ('reg_lambda', 0.16000000000000003), ('gamma', 0.5)]),
#   0.7975235072017147],
#  [dict_items([('max_depth', 8), ('subsample', 0.4), ('colsample_bytree', 0.4), ('reg_lambda', 0.36), ('gamma', 5)]),
#   0.7972458651757779],
#  [dict_items([('max_depth', 4), ('subsample', 0.7), ('colsample_bytree', 0.4), ('reg_lambda', 0.48999999999999994)]),
#   0.7972437829457018],
#  [dict_items([('max_depth', 6), ('subsample', 0.5), ('colsample_bytree', 0.4), ('reg_lambda', 0.16000000000000003), ('gamma', 0.01)]),
#   0.797220077689003],
#  [dict_items([('max_depth', 4), ('subsample', 0.7), ('colsample_bytree', 0.9), ('reg_lambda', 0.36)]),
#   0.7970510584843484],
#  [dict_items([('max_depth', 5), ('subsample', 0.6), ('colsample_bytree', 0.8), ('reg_lambda', 0.48999999999999994)]),
#   0.7960699531691382],
#  [dict_items([('max_depth', 4), ('subsample', 0.6), ('colsample_bytree', 0.7), ('reg_lambda', 0.25)]),
#   0.796019227458126],
#  [dict_items([('max_depth', 6), ('subsample', 0.8), ('colsample_bytree', 0.9), ('reg_lambda', 0.25)]),
#   0.7959741505547424],
#  [dict_items([('max_depth', 4), ('subsample', 0.5), ('colsample_bytree', 0.9), ('reg_lambda', 0.36), ('gamma', 0)]),
#   0.795618582898213],
#  [dict_items([('max_depth', 4), ('subsample', 0.5), ('colsample_bytree', 0.8), ('reg_lambda', 0.48999999999999994), ('gamma', 5)]),
#   0.795015583731862],
#  [dict_items([('max_depth', 6), ('subsample', 0.3), ('colsample_bytree', 0.3), ('reg_lambda', 0.25), ('gamma', 0.5)]),
#   0.7950130410572622],
#  [dict_items([('max_depth', 7), ('subsample', 0.4), ('colsample_bytree', 0.4), ('reg_lambda', 0.16000000000000003), ('gamma', 1)]),
#   0.7950066674653105],
#  [dict_items([('max_depth', 7), ('subsample', 0.6), ('colsample_bytree', 0.8), ('reg_lambda', 0.48999999999999994), ('gamma', 0.01)]),
#   0.7943748587335372],
#  [dict_items([('max_depth', 5), ('subsample', 0.4), ('colsample_bytree', 0.7), ('reg_lambda', 0.04000000000000001)]),
#   0.7939456752136586],
#  [dict_items([('max_depth', 8), ('subsample', 0.8), ('colsample_bytree', 0.7), ('reg_lambda', 0.09)]),
#   0.7938878185272213],
#  [dict_items([('max_depth', 9), ('subsample', 0.8), ('colsample_bytree', 0.6), ('reg_lambda', 0.09)]),
#   0.7934903609480028],
#  [dict_items([('max_depth', 4), ('subsample', 0.3), ('colsample_bytree', 0.8), ('reg_lambda', 0.04000000000000001)]),
#   0.7933666048505356],
#  [dict_items([('max_depth', 8), ('subsample', 0.8), ('colsample_bytree', 0.9), ('reg_lambda', 0.25)]),
#   0.7930027609406873],
#  [dict_items([('max_depth', 12), ('subsample', 0.9), ('colsample_bytree', 0.4), ('reg_lambda', 0.04000000000000001), ('gamma', 1)]),
#   0.7928616950343857],
#  [dict_items([('max_depth', 7), ('subsample', 0.4), ('colsample_bytree', 0.9), ('reg_lambda', 0.48999999999999994), ('gamma', 0.5)]),
#   0.7918065429071793],
#  [dict_items([('max_depth', 10), ('subsample', 0.8), ('colsample_bytree', 0.6), ('reg_lambda', 0.48999999999999994)]),
#   0.7916089152735631],
#  [dict_items([('max_depth', 9), ('subsample', 0.7), ('colsample_bytree', 0.9), ('reg_lambda', 0.09)]),
#   0.7913818123853975],
#  [dict_items([('max_depth', 10), ('subsample', 0.6), ('colsample_bytree', 0.5), ('reg_lambda', 0.36), ('gamma', 0.1)]),
#   0.7902448706603826],
#  [dict_items([('max_depth', 7), ('subsample', 0.4), ('colsample_bytree', 0.9), ('reg_lambda', 0.48999999999999994)]),
#   0.79020652282894],
#  [dict_items([('max_depth', 9), ('subsample', 0.5), ('colsample_bytree', 0.5), ('reg_lambda', 0.09)]),
#   0.7898745577255312],
#  [dict_items([('max_depth', 8), ('subsample', 0.4), ('colsample_bytree', 0.9), ('reg_lambda', 0.48999999999999994), ('gamma', 2)]),
#   0.7896643551840279],
#  [dict_items([('max_depth', 13), ('subsample', 0.9), ('colsample_bytree', 0.7), ('reg_lambda', 0.36), ('gamma', 0.5)]),
#   0.7889846339400225],
#  [dict_items([('max_depth', 11), ('subsample', 0.9), ('colsample_bytree', 0.7), ('reg_lambda', 0.16000000000000003)]),
#   0.7886757233368417],
#  [dict_items([('max_depth', 9), ('subsample', 0.5), ('colsample_bytree', 0.6), ('reg_lambda', 0.16000000000000003), ('gamma', 0)]),
#   0.7884978318434553],
#  [dict_items([('max_depth', 9), ('subsample', 0.5), ('colsample_bytree', 0.7), ('reg_lambda', 0.16000000000000003), ('gamma', 0.01)]),
#   0.7879325404953141],
#  [dict_items([('max_depth', 12), ('subsample', 0.5), ('colsample_bytree', 0.3), ('reg_lambda', 0.48999999999999994)]),
#   0.7878059562664097],
#  [dict_items([('max_depth', 8), ('subsample', 0.3), ('colsample_bytree', 0.7), ('reg_lambda', 0.48999999999999994), ('gamma', 0)]),
#   0.7865741303925378],
#  [dict_items([('max_depth', 13), ('subsample', 0.8), ('colsample_bytree', 0.8), ('reg_lambda', 0.16000000000000003)]),
#   0.7862557179424685],
#  [dict_items([('max_depth', 11), ('subsample', 0.6), ('colsample_bytree', 0.6), ('reg_lambda', 0.09), ('gamma', 1)]),
#   0.7858604045036344],
#  [dict_items([('max_depth', 10), ('subsample', 0.5), ('colsample_bytree', 0.8), ('reg_lambda', 0.36), ('gamma', 1)]),
#   0.7846607397084888],
#  [dict_items([('max_depth', 9), ('subsample', 0.3), ('colsample_bytree', 0.6), ('reg_lambda', 0.36)]),
#   0.7846100099927759],
#  [dict_items([('max_depth', 13), ('subsample', 0.8), ('colsample_bytree', 0.8), ('reg_lambda', 0.36), ('gamma', 0)]),
#   0.7844193891445316],
#  [dict_items([('max_depth', 9), ('subsample', 0.3), ('colsample_bytree', 0.5), ('reg_lambda', 0.09), ('gamma', 0.01)]),
#   0.7841574946286757],
#  [dict_items([('max_depth', 12), ('subsample', 0.7), ('colsample_bytree', 0.7), ('reg_lambda', 0.04000000000000001), ('gamma', 0.1)]),
#   0.7839066531457864],
#  [dict_items([('max_depth', 11), ('subsample', 0.6), ('colsample_bytree', 0.8), ('reg_lambda', 0.25)]),
#   0.7834966274784939],
#  [dict_items([('max_depth', 11), ('subsample', 0.5), ('colsample_bytree', 0.8), ('reg_lambda', 0.16000000000000003), ('gamma', 2)]),
#   0.7820646277424187],
#  [dict_items([('max_depth', 13), ('subsample', 0.5), ('colsample_bytree', 0.6), ('reg_lambda', 0.04000000000000001), ('gamma', 1)]),
#   0.7818097396424972],
#  [dict_items([('max_depth', 13), ('subsample', 0.5), ('colsample_bytree', 0.7), ('reg_lambda', 0.48999999999999994), ('gamma', 0)]),
#   0.7817965568476473],
#  [dict_items([('max_depth', 13), ('subsample', 0.6), ('colsample_bytree', 0.6), ('reg_lambda', 0.48999999999999994)]),
#   0.7817065499069971],
#  [dict_items([('max_depth', 13), ('subsample', 0.6), ('colsample_bytree', 0.9), ('reg_lambda', 0.36)]),
#   0.7797756662101412]]

# %%
def find_features(data):
    X_train, X_test, y_train, y_test = train_test_split(data[features], data_le['y'], test_size=0.25)
    model = XGBClassifier(max_depth=5, subsample=0.9, colsample_bytree=0.4, reg_lambda=0.36, use_label_encoder=False)
    model.fit(X_test, y_test)
    feature_importances = []
    importance_values = model.feature_importances_
    importance_names = X_train.columns.tolist()
    for i in range(len(importance_values)):
        feature_importances.append([importance_names[i], importance_values[i]])
    sorted_importances = sorted(feature_importances, key=lambda x: x[-1], reverse=True)
    return sorted_importances

# %%
find_features(data_le)
# Out:
# [20:13:40] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [['martial_status', 0.3233115],
#  ['capital_gain', 0.13365893],
#  ['education_num', 0.1179173],
#  ['sex', 0.09177802],
#  ['relationship', 0.076752335],
#  ['capital_loss', 0.05240771],
#  ['age', 0.044324327],
#  ['occupation', 0.043233737],
#  ['hours_per_week', 0.030805232],
#  ['fnlwgt', 0.020445198],
#  ['workclass', 0.018302206],
#  ['education', 0.017441545],
#  ['race', 0.015688144],
#  ['naive_country', 0.013933842]]

# %%
feature_importances = []
importance_values = best_model.feature_importances_
importance_names = X_train.columns.tolist()
for i in range(len(importance_values)):
    feature_importances.append([importance_names[i], importance_values[i]])
sorted_importances = sorted(feature_importances, key=lambda x: x[-1], reverse=True)

# %%
sorted_importances
# Out:
# [['martial_status', 0.26695514],
#  ['capital_gain', 0.14750516],
#  ['relationship', 0.1365918],
#  ['sex', 0.10572314],
#  ['education_num', 0.09393712],
#  ['capital_loss', 0.047303792],
#  ['occupation', 0.044974726],
#  ['age', 0.044208914],
#  ['hours_per_week', 0.024951177],
#  ['fnlwgt', 0.021042665],
#  ['education', 0.01846338],
#  ['workclass', 0.018258749],
#  ['race', 0.016831458],
#  ['naive_country', 0.013252837]]

# %%
import pickle 
with open('xgb_info.pkl', 'wb') as f:
    pickle.dump(sorted_importances, f)
